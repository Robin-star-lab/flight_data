# %% [markdown]
# **UNDERSTANDING OF THE DATA**

# %%
# Importation of various libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
# Data aquisition
df=pd.read_csv('flight_dataset.csv')
df.head(5)
# Out:
#        Airline    Source Destination  Total_Stops  Price  Date  Month  Year  \
# 0       IndiGo  Banglore   New Delhi            0   3897    24      3  2019
# 1    Air India   Kolkata    Banglore            2   7662     1      5  2019
# 2  Jet Airways     Delhi      Cochin            2  13882     9      6  2019
# 3       IndiGo   Kolkata    Banglore            1   6218    12      5  2019
# 4       IndiGo  Banglore   New Delhi            1  13302     1      3  2019
#
#    Dep_hours  Dep_min  Arrival_hours  Arrival_min  Duration_hours  \
# 0         22       20              1           10               2
# 1          5       50             13           15               7
# 2          9       25              4           25              19
# 3         18        5             23           30               5
# 4         16       50             21           35               4
#
#    Duration_min
# 0            50
# 1            25
# 2             0
# 3            25
# 4            45

# %%
df.columns
# Out:
# Index(['Airline', 'Source', 'Destination', 'Total_Stops', 'Price', 'Date',
#        'Month', 'Year', 'Dep_hours', 'Dep_min', 'Arrival_hours', 'Arrival_min',
#        'Duration_hours', 'Duration_min'],
#       dtype='object')

# %%
df.shape
# Out:
# (10683, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Airline         10683 non-null  object
#  1   Source          10683 non-null  object
#  2   Destination     10683 non-null  object
#  3   Total_Stops     10683 non-null  int64
#  4   Price           10683 non-null  int64
#  5   Date            10683 non-null  int64
#  6   Month           10683 non-null  int64
#  7   Year            10683 non-null  int64
#  8   Dep_hours       10683 non-null  int64
#  9   Dep_min         10683 non-null  int64
#  10  Arrival_hours   10683 non-null  int64
#  11  Arrival_min     10683 non-null  int64
#  12  Duration_hours  10683 non-null  int64
#  13  Duration_min    10683 non-null  int64
# dtypes: int64(11), object(3)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#         Total_Stops         Price          Date         Month     Year  \
# count  10683.000000  10683.000000  10683.000000  10683.000000  10683.0
# mean       0.824207   9087.064121     13.508378      4.708602   2019.0
# std        0.675199   4611.359167      8.479277      1.164357      0.0
# min        0.000000   1759.000000      1.000000      3.000000   2019.0
# 25%        0.000000   5277.000000      6.000000      3.000000   2019.0
# 50%        1.000000   8372.000000     12.000000      5.000000   2019.0
# 75%        1.000000  12373.000000     21.000000      6.000000   2019.0
# max        4.000000  79512.000000     27.000000      6.000000   2019.0
#
#           Dep_hours       Dep_min  Arrival_hours   Arrival_min  \
# count  10683.000000  10683.000000   10683.000000  10683.000000
# mean      12.490686     24.411214      13.348778     24.690630
# std        5.748650     18.767980       6.859125     16.506036
# min        0.000000      0.000000       0.000000      0.000000
# ...

# %%
df['Year'].unique
# Out:
# <bound method Series.unique of 0        2019
# 1        2019
# 2        2019
# 3        2019
# 4        2019
#          ...
# 10678    2019
# 10679    2019
# 10680    2019
# 10681    2019
# 10682    2019
# Name: Year, Length: 10683, dtype: int64>

# %% [markdown]
# The data is aflight dataset for 2019.

# %%
df['Month'].value_counts()
# Out:
# Month
# 5    3466
# 6    3414
# 3    2724
# 4    1079
# Name: count, dtype: int64

# %% [markdown]
# The flights occured between April and june.

# %% [markdown]
# May had most flights

# %%
sorted_df=df.sort_values(by='Price',ascending=False)
sorted_df
# Out:
#                     Airline    Source Destination  Total_Stops  Price  Date  \
# 2924   Jet Airways Business  Banglore   New Delhi            1  79512     1
# 5372   Jet Airways Business  Banglore   New Delhi            1  62427     1
# 10364  Jet Airways Business  Banglore   New Delhi            1  57209     1
# 1478            Jet Airways  Banglore   New Delhi            1  54826    18
# 5439            Jet Airways  Banglore   New Delhi            1  54826     1
# ...                     ...       ...         ...          ...    ...   ...
# 1513            Jet Airways    Mumbai   Hyderabad            0   1840    27
# 10513              SpiceJet    Mumbai   Hyderabad            0   1759    27
# 4839               SpiceJet    Mumbai   Hyderabad            0   1759     3
# 4066               SpiceJet    Mumbai   Hyderabad            0   1759    21
# 4274               SpiceJet    Mumbai   Hyderabad            0   1759    27
#
# ...

# %%
sorted_df=df.sort_values(by='Price',ascending=True)
sorted_df
# Out:
#                     Airline    Source Destination  Total_Stops  Price  Date  \
# 4066               SpiceJet    Mumbai   Hyderabad            0   1759    21
# 10513              SpiceJet    Mumbai   Hyderabad            0   1759    27
# 4839               SpiceJet    Mumbai   Hyderabad            0   1759     3
# 4274               SpiceJet    Mumbai   Hyderabad            0   1759    27
# 1513            Jet Airways    Mumbai   Hyderabad            0   1840    27
# ...                     ...       ...         ...          ...    ...   ...
# 1478            Jet Airways  Banglore   New Delhi            1  54826    18
# 5439            Jet Airways  Banglore   New Delhi            1  54826     1
# 10364  Jet Airways Business  Banglore   New Delhi            1  57209     1
# 5372   Jet Airways Business  Banglore   New Delhi            1  62427     1
# 2924   Jet Airways Business  Banglore   New Delhi            1  79512     1
#
# ...

# %% [markdown]
# Spicejet from Mumbai to Hyderabad is the least charged flight.

# %% [markdown]
# JetAirways from Bangallore to Newdelhi was the had the highest price.

# %%
df.isnull()
# Out:
#        Airline  Source  Destination  Total_Stops  Price   Date  Month   Year  \
# 0        False   False        False        False  False  False  False  False
# 1        False   False        False        False  False  False  False  False
# 2        False   False        False        False  False  False  False  False
# 3        False   False        False        False  False  False  False  False
# 4        False   False        False        False  False  False  False  False
# ...        ...     ...          ...          ...    ...    ...    ...    ...
# 10678    False   False        False        False  False  False  False  False
# 10679    False   False        False        False  False  False  False  False
# 10680    False   False        False        False  False  False  False  False
# 10681    False   False        False        False  False  False  False  False
# 10682    False   False        False        False  False  False  False  False
#
# ...

# %% [markdown]
# The data has no missing values

# %%
df['Airline'].value_counts()
# Out:
# Airline
# Jet Airways                          3849
# IndiGo                               2053
# Air India                            1752
# Multiple carriers                    1196
# SpiceJet                              818
# Vistara                               479
# Air Asia                              319
# GoAir                                 194
# Multiple carriers Premium economy      13
# Jet Airways Business                    6
# Vistara Premium economy                 3
# Trujet                                  1
# Name: count, dtype: int64

# %% [markdown]
# JetAirways is the most used Airline

# %%
# Knowing the most flied to destination
df['Destination'].value_counts()
# Out:
# Destination
# Cochin       4537
# Banglore     2871
# Delhi        1265
# New Delhi     932
# Hyderabad     697
# Kolkata       381
# Name: count, dtype: int64

# %% [markdown]
# Cochin is the most flied to destination.

# %%
df['Source'].value_counts()
# Out:
# Source
# Delhi       4537
# Kolkata     2871
# Banglore    2197
# Mumbai       697
# Chennai      381
# Name: count, dtype: int64

# %% [markdown]
# Most flights came from Delhi

# %%
def airline():
    for x in df['Airline']:
        if (df['Total_Stops']==0) & (df['Destination']=='Cochin'):
            print(x)
            airline();
